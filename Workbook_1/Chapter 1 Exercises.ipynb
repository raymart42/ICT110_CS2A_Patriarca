# %% [markdown]
# <a id='chapter1'></a>

# %% [markdown]
# # CHAPTER 1 - Introduction

# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
#Print('Hello world!')

print('Hello world!')
#print is in big letter "Print"
# Out:
# Hello world!

# %%
#print'Hello world!')

print('Hello world!')
#lacks an open parenthesis
# Out:
# Hello world!

# %%
#print('Hello world!)

print('Hello world!')
#lacks a closing quotation mark
# Out:
# Hello world!

# %%
#print('Hello world!'')

print('Hello world!')
#there's an extra closing quotation at the end
# Out:
# Hello world!

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)
#output is 44
# Out:
# 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1
print(x)
#the variable is in upper case
# Out:
# 44
